# %%
pip install pandas
# Out:
# 429.37s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# 441.17s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 4.2 MB/s eta 0:00:0000:0100:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 4.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 4.1 MB/s eta 0:00:00a 0:00:01
# Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('../data/articles_annotated.csv')

# Calculate percentage distribution
code_percentages = df['coding'].value_counts(normalize=True) * 100

# Plot a bar chart with default colors
plt.figure(figsize=(10, 6))
plt.bar(code_percentages.index, code_percentages.values)

# Add labels and title
plt.title('Percentage Distribution of Coding Categories in News Articles')
plt.xlabel('Coding Categories')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=45)
plt.show()
